# %%
import cv2
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %%
check = cv2.VideoCapture("video-assignment-1.mp4")
if (check.isOpened == False):
    print("video cannot be loaded")
else:
    count = check.get(7)
    print("Number of frames is: ",count)
# Out:
# Number of frames is:  330.0

# %%
import videokf as vf
vf.extract_keyframes("video-assignment-1.mp4")
print(vf)
# Out:
# ...
# Iframes successfully extracted.
# <module 'videokf' from 'C:\\Users\\SOUMILI MUKHERJEE\\anaconda3\\lib\\site-packages\\videokf\\__init__.py'>

# %%
keyframes=[]
for i in range(12):
    keyframes.append(mpimg.imread(f"{29*i}.jpg"))

# %%
for i in range(12):
    imgplot=plt.imshow(keyframes[i])
    plt.show()
